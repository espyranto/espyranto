# %%
import sys
# This seems to be needed to load user installed modules
sys.path.insert(0, '/global/u2/j/jkitchin/.local/cori/3.7-anaconda-2019.10/lib/python3.7/site-packages')

from espyranto.g1.plate import Plate
from espyranto.g1.mmolH import mmolH

# %%
p = Plate('/global/u2/j/jkitchin/generation-1-data/02/PdcolSnrow')
print(p)
# Out:
# PdcolSnrow
# H2 Evo - Alloy Nanopart.
# 2019-02-09 00:00:00
# Pd Columns Sn Rows
# In DMSO
# 10:1 solvent to water
# TEOA
# Solution Volume (mL)
# 0.45
# A=Pd
# B=Sn
#
# mmolH data
#   118 images were acquired.
#   Start time: 2019-02-09 16:36:18
#   End time: 2019-02-10 12:15:44
#   The timestep is 600 s
#   mmolH data has shape: (96, 74)

# %%
p.metadata['A']
# Out:
# 'Pd'

# %%
mmolH = p.data['mmolH']
mmolH.maxh()
# Out:
# (28, 37.48418383379452)

# %%
mmolH.plot_mmolH([1, 11])

# %%
mmolH.plot_mmolH_grid();  # ; suppresses a lot of matplotlib output

# %%
mmolH.plot_mmolH_max()

# %%
mmolH.show_plate(slice(0, -1, 20));
